# %% [markdown]
# # SVM for Posture Recognition
# ### Accuracy - 93.7%

# %%
# importing necessary libraries
import numpy as np 
import pandas as pd
import os
from sklearn import svm
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage.io import imread
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
import pickle

# %%
Categories=['Slouching','Upright','Writing']
flat_data_arr=[]
target_arr=[]

datadir=r'D:\CSE @ RV\VI SEM\AA\self study\New Plant Diseases Dataset(Augmented)\New Plant Diseases Dataset(Augmented)\dataset'
for i in Categories:
    print(f'loading... category : {i}')
    path=os.path.join(datadir,i)
    for img in os.listdir(path):
        img_array=imread(os.path.join(path,img))
        img_resized=resize(img_array,(150,150,3))
        flat_data_arr.append(img_resized.flatten())
        target_arr.append(Categories.index(i))
    print(f'loaded category:{i} successfully')
flat_data=np.array(flat_data_arr)
target=np.array(target_arr)
df=pd.DataFrame(flat_data)
df['Target']=target
df
# Out:
# loading... category : Slouching
# loaded category:Slouching successfully
# loading... category : Upright
# loaded category:Upright successfully
# loading... category : Writing
# loaded category:Writing successfully
#              0         1         2         3         4         5         6  \
# 0     0.627623  0.627623  0.627623  0.540783  0.540783  0.540783  0.464417
# 1     0.627623  0.627623  0.627623  0.540783  0.540783  0.540783  0.464417
# 2     0.616321  0.616321  0.616321  0.538594  0.538594  0.538594  0.455331
# 3     0.629389  0.629389  0.629389  0.542864  0.542859  0.542862  0.473119
# 4     0.613984  0.613984  0.613984  0.526109  0.526109  0.526109  0.452842
# ...        ...       ...       ...       ...       ...       ...       ...
# 3935  0.004301  0.004433  0.006195  0.004401  0.004710  0.007227  0.004490
# 3936  0.004580  0.003236  0.002241  0.003726  0.003283  0.002207  0.003222
# 3937  0.007649  0.003704  0.003906  0.005341  0.003677  0.006515  0.006108
# ...

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=77,stratify=y)
print('Split Successfully')
# Out:
# Split Successfully

# %%
# training a rbf SVM classifier
from sklearn.svm import SVC
svm_model_rbf2 = SVC(kernel = 'rbf', C = 0.1).fit(x_train, y_train)
svm_predictions_rbf2 = svm_model_rbf2.predict(x_test)

# %%
# model accuracy for X_test 
accuracy_rbf2 = svm_model_rbf2.score(x_test, y_test)
accuracy_rbf2
# Out:
# 0.9370558375634518

# %%
# creating a confusion matrix
cm_rbf2 = confusion_matrix(y_test, svm_predictions_rbf2)
cm_df = pd.DataFrame(cm_rbf2,
                     index = ['Slouching','Upright','Writing'], 
                     columns = ['Slouching','Upright','Writing'])
#Plotting the confusion matrix
import seaborn as sns
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True, fmt = "d", cmap = "Blues")
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()
